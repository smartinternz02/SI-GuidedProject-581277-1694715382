# %% [markdown]
# NAME : MYDUKURI RADHA KOMALIDEVI
# REG NO: 21BCE9071

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Task-1 Createt a pandas (Data frame name as 'df') (10 observations and 5 features)

# %%
df=pd.read_csv("/content/sample_data/mtcars.csv")
df
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
df.head()
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
df.tail()
# Out:
#              model   mpg  cyl   disp   hp  drat     wt  qsec  vs  am  gear  \
# 27    Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.9   1   1     5
# 28  Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.5   0   1     5
# 29    Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.5   0   1     5
# 30   Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.6   0   1     5
# 31      Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.6   1   1     4
#
#     carb
# 27     2
# 28     4
# 29     6
# 30     8
# 31     2

# %% [markdown]
# Task-2 Check the info of 'df'

# %%
df.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %% [markdown]
# Task-4 Check the 4th index observation with 'loc' slicing operator.

# %%
df.loc[3:3, :]
# Out:
#             model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 3  Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
#
#    carb
# 3     1

# %% [markdown]
# Task-5 Check the null values in your 'df'

# %%
df.isnull().any()
# Out:
# model    False
# mpg      False
# cyl      False
# disp     False
# hp       False
# drat     False
# wt       False
# qsec     False
# vs       False
# am       False
# gear     False
# carb     False
# dtype: bool

# %% [markdown]
# ASSIGNMENT-1
# Task-1 Create a pandas dataframe(DataFrame name as 'df') with numpy random values(4 features and 4 observations)

# %%
data=np.random.rand(4,4)
df=pd.DataFrame(data, columns=['Feature1', 'Feature2', 'Feature3','Feature4'])
df
# Out:
#    Feature1  Feature2  Feature3  Feature4
# 0  0.980312  0.362363  0.004675  0.714963
# 1  0.439609  0.408548  0.446308  0.730966
# 2  0.947101  0.012862  0.898208  0.227746
# 3  0.270643  0.678466  0.340716  0.305615

# %% [markdown]
# Task-2 Rename the task-1 'df' dataframe column names to 'Random Values 1', 'Random Values 2', 'Random Values 3', &'Random Values 4'

# %%
new_column_names=['Random Values 1','Random Values 2','Random Values 3','Random Values 4']
df.columns=new_column_names
df
# Out:
#    Random Values 1  Random Values 2  Random Values 3  Random Values 4
# 0         0.980312         0.362363         0.004675         0.714963
# 1         0.439609         0.408548         0.446308         0.730966
# 2         0.947101         0.012862         0.898208         0.227746
# 3         0.270643         0.678466         0.340716         0.305615

# %% [markdown]
# Task-3 Find the descriptive statisics of the 'df' dataframe.

# %%
df.describe()
# Out:
#        Random Values 1  Random Values 2  Random Values 3  Random Values 4
# count         4.000000         4.000000         4.000000         4.000000
# mean          0.659416         0.365560         0.422477         0.494822
# std           0.358328         0.273352         0.368841         0.265427
# min           0.270643         0.012862         0.004675         0.227746
# 25%           0.397367         0.274988         0.256706         0.286148
# 50%           0.693355         0.385456         0.393512         0.510289
# 75%           0.955404         0.476028         0.559283         0.718964
# max           0.980312         0.678466         0.898208         0.730966

# %% [markdown]
# Task-4 Check for the null values in 'df' and find the datatype of the columns.

# %%
df.isnull().any()
# Out:
# Random Values 1    False
# Random Values 2    False
# Random Values 3    False
# Random Values 4    False
# dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Random Values 1  4 non-null      float64
#  1   Random Values 2  4 non-null      float64
#  2   Random Values 3  4 non-null      float64
#  3   Random Values 4  4 non-null      float64
# dtypes: float64(4)
# memory usage: 256.0 bytes

# %% [markdown]
# Task-5 Display the 'Random value 2' & 'Random value 3' columns with location method and index location method

# %%
df.loc[:,'Random values 2':'Random values 3']
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3]

# %%
df.iloc[:,1:3]
# Out:
#    Random Values 2  Random Values 3
# 0         0.362363         0.004675
# 1         0.408548         0.446308
# 2         0.012862         0.898208
# 3         0.678466         0.340716
